# %%
import pandas as pd
import googlemaps

# %%
df = pd.read_excel(r"C:\Users\jonat\Desktop\ShopAddresses.xlsx") #past file path, exp:"C:\Users\jonat\Desktop\addresses.xlsx"
df
# Out:
#                                              Shop Name  \
# 0               BERJAYA TIMES SQUARE EXPERIENCE CENTRE
# 1               BERJAYA TIMES SQUARE EXPERIENCE CENTRE
# 2    U MOBILE SERVICE CENTRE, AEON AU2 SHOPPING CENTRE
# 3         U MOBILE SERVICE CENTRE, BUKIT TINGGI, KLANG
# 4              U MOBILE SERVICE CENTRE, SUNWAY PYRAMID
# ..                                                 ...
# 151                       E.Q COMMUNICATION ENTERPRISE
# 152                             AZ BROADBAND SOLUTIONS
# 153                                  BONACO ENTERPRISE
# 154                                      JJCOM TRADING
# 155                                   HELLO PHONE SHOP
#
#                                           Shop Address
# 0    G17, GROUND FLOOR, EAST WING, BERJAYA TIMES SQ...
# 1    NO. 1-10, LEVEL 1, BERJAYA TIMES SQUARE, NO. 1...
# 2    G11, AEON AU2 SHOPPING CENTRE, NO 6, JALAN TAM...
# 3    B-G-10, GROUND FLOOR, BBT ONE, LEBUH BATU NILA...
# ...

# %%
gmaps_key = googlemaps.Client(key = "") # paste api key in double quotes

# %%
df.iat[1,1] #ensure correct loop correct row
# Out:
# 'NO. 1-10, LEVEL 1, BERJAYA TIMES SQUARE, NO. 1, JALAN IMBI, 55100 KUALA LUMPUR.'

# %%
for i in range(0, len(df), 1): #Ensure loop trhough correct row
    print(df.iat[i,1])
# Out:
# G17, GROUND FLOOR, EAST WING, BERJAYA TIMES SQUARE, NO. 1, JALAN IMBI, 55100 KUALA LUMPUR.
# NO. 1-10, LEVEL 1, BERJAYA TIMES SQUARE, NO. 1, JALAN IMBI, 55100 KUALA LUMPUR.
# G11, AEON AU2 SHOPPING CENTRE, NO 6, JALAN TAMAN SETIA WANGSA, AU2, BANDAR BARU AMPANG, MUKIM ULU KELANG, 54200 KUALA LUMPUR
# B-G-10, GROUND FLOOR, BBT ONE, LEBUH BATU NILAM 2, BANDAR BUKIT TINGGI,41200 KLANG, SELANGOR.
# LOT F1.26, 1ST FLOOR, SUNWAY PYRAMID, NO. 3, JALAN PJS 11/15, BANDAR SUNWAY, 46150 PETALING JAYA, SELANGOR.
# LG313C, 1UTAMA SHOPPING CENTRE (NEW WING), 1, PERSIARAN BANDAR UTAMA, BANDAR UTAMA, 47100 PETALING JAYA, SELANGOR.
# 2F- 33A & 35 (2ND FLOOR), QUEENSBAY MALL, 100, PERSIARAN BAYAN INDAH, BAYAN LEPAS, 11900, PULAU PINANG.
# NO. 50, GROUND FLOOR, JALAN TODAK 2, 13700 SEBERANG JAYA, PULAU PINANG.
# NO. 3, GROUND FLOOR, JALAN MERDEKA, TAMAN MELAKA RAYA, 75250 MELAKA.
# GROUND FLOOR, NO. 135-1, JALAN TUN DR. ISMAIL, 70200 SEREMBAN, NEGERI SEMBILAN
# ...

# %%
df["LAT"] = None
df["LON"] = None

for i in range(0, len(df), 1):
    geocode_result = gmaps_key.geocode(df.iat[i,1])
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        df.iat[i, df.columns.get_loc("LAT")] = lat
        df.iat[i, df.columns.get_loc("LON")] = lon
    except:
        lat = None
        lon = None

# %%
df # paste the LAT and LON in the google maps to see result
# Out:
#                                              Shop Name  \
# 0               BERJAYA TIMES SQUARE EXPERIENCE CENTRE
# 1               BERJAYA TIMES SQUARE EXPERIENCE CENTRE
# 2    U MOBILE SERVICE CENTRE, AEON AU2 SHOPPING CENTRE
# 3         U MOBILE SERVICE CENTRE, BUKIT TINGGI, KLANG
# 4              U MOBILE SERVICE CENTRE, SUNWAY PYRAMID
# ..                                                 ...
# 151                       E.Q COMMUNICATION ENTERPRISE
# 152                             AZ BROADBAND SOLUTIONS
# 153                                  BONACO ENTERPRISE
# 154                                      JJCOM TRADING
# 155                                   HELLO PHONE SHOP
#
#                                           Shop Address      LAT      LON
# 0    G17, GROUND FLOOR, EAST WING, BERJAYA TIMES SQ...  3.14216  101.711
# 1    NO. 1-10, LEVEL 1, BERJAYA TIMES SQUARE, NO. 1...  3.14216  101.711
# 2    G11, AEON AU2 SHOPPING CENTRE, NO 6, JALAN TAM...  3.17703  101.751
# ...

# %%
df.to_csv(r'C:\Users\jonat\Desktop\ShopAddressesLongLat.csv', index = False)
